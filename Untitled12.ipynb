# %%
import iris
import iris.coord_categorisation

obs_cube_all = iris.load_cube('/Users/ph290/Downloads/obs_data/CCI_ALL-v4.2-MONTHLY_region.nc')

iris.coord_categorisation.add_year(obs_cube_all, 'time', name='year')

# obs_cube_all = obs_cube_all.aggregated_by('year', iris.analysis.MEAN)
# Out:
# /Users/ph290/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/fileformats/cf.py:285: UserWarning: Missing CF-netCDF ancillary data variable 'chlor_a_log10_rmsd', referenced by netCDF variable 'chlor_a'
#   warnings.warn(message % (name, nc_var_name))
# /Users/ph290/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/fileformats/cf.py:285: UserWarning: Missing CF-netCDF ancillary data variable 'chlor_a_log10_bias', referenced by netCDF variable 'chlor_a'
#   warnings.warn(message % (name, nc_var_name))
# ---------------------------------------------------------------------------
# CoordinateNotFoundError                   Traceback (most recent call last)
# <ipython-input-13-da2527e34433> in <module>
#      13     pass
#      14
# ---> 15 obs_cube_all = obs_cube_all.aggregated_by('year', iris.analysis.MEAN)
#
# ~/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/cube.py in aggregated_by(self, coords, aggregator, **kwargs)
#    4112             )
#    4113
# -> 4114         coords = self._as_list_of_coords(coords)
#    4115         for coord in sorted(coords, key=lambda coord: coord.metadata):
#    4116             if coord.ndim > 1:
#
# ~/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/cube.py in _as_list_of_coords(self, names_or_coords)
#    3235                 name_or_coord, iris.coords.Coord
#    3236             ):
# -> 3237                 coords.append(self.coord(name_or_coord))
#    3238             else:
#    3239                 # Don't know how to handle this type
#
# ~/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/cube.py in coord(self, name_or_coord, standard_name, long_name, var_name, attributes, axis, contains_dimension, dimensions, coord_system, dim_coords)
#    1827                 "none." % bad_name
#    1828             )
# -> 1829             raise iris.exceptions.CoordinateNotFoundError(msg)
#    1830
#    1831         return coords[0]
#
# CoordinateNotFoundError: 'Expected to find exactly 1 year coordinate, but found none.'

# %%
iris.coord_categorisation.add_year(obs_cube_all, 'time', name='year')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-abe1a865b06c> in <module>
# ----> 1 iris.coord_categorisation.add_year(obs_cube_all, 'time', name='year')
#
# ~/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/coord_categorisation.py in add_year(cube, coord, name)
#     117 def add_year(cube, coord, name="year"):
#     118     """Add a categorical calendar-year coordinate."""
# --> 119     add_categorised_coord(
#     120         cube, name, coord, lambda coord, x: _pt_date(coord, x).year
#     121     )
#
# ~/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/coord_categorisation.py in add_categorised_coord(cube, name, from_coord, category_function, units)
#      63     # Test whether the result contains strings. If it does we must manually
#      64     # force the dtype because of a numpy bug (see numpy #3270 on GitHub).
# ---> 65     result = category_function(from_coord, from_coord.points.ravel()[0])
#      66     if isinstance(result, str):
#      67         str_vectorised_fn = np.vectorize(category_function, otypes=[object])
#
# ~/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/coord_categorisation.py in <lambda>(coord, x)
#     118     """Add a categorical calendar-year coordinate."""
#     119     add_categorised_coord(
# --> 120         cube, name, coord, lambda coord, x: _pt_date(coord, x).year
#     121     )
#     122
#
# ~/opt/miniconda3/envs/mypython3/lib/python3.9/site-packages/iris/coord_categorisation.py in _pt_date(coord, time)
#     108     # NOTE: All of the currently defined categorisation functions are
#     109     # calendar operations on Time coordinates.
# --> 110     return coord.units.num2date(time, only_use_cftime_datetimes=True)
#     111
#     112
#
# TypeError: num2date() got an unexpected keyword argument 'only_use_cftime_datetimes'

# %%
obs_cube_all
# Out:
# <iris 'Cube' of mass_concentration_of_chlorophyll_a_in_sea_water / (milligram m-3) (time: 268; latitude: 528; longitude: 720)>
