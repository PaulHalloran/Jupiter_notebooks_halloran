# %%
import iris
import iris.plot as iplt
import matplotlib.pyplot as plt

# %%
file = '/Users/ph290/Downloads/download_timmean.nc'

# %%
cs= iris.load(file)

# %%
cs
# Out:
# [<iris 'Cube' of Surface thermal radiation downwards / (J m**-2) (time: 1; latitude: 721; longitude: 1440)>,
# <iris 'Cube' of surface_downwelling_shortwave_flux_in_air / (J m**-2) (time: 1; latitude: 721; longitude: 1440)>,
# <iris 'Cube' of surface_net_downward_shortwave_flux / (J m**-2) (time: 1; latitude: 721; longitude: 1440)>,
# <iris 'Cube' of surface_net_upward_longwave_flux / (J m**-2) (time: 1; latitude: 721; longitude: 1440)>,
# <iris 'Cube' of surface_upward_latent_heat_flux / (J m**-2) (time: 1; latitude: 721; longitude: 1440)>,
# <iris 'Cube' of surface_upward_sensible_heat_flux / (J m**-2) (time: 1; latitude: 721; longitude: 1440)>]

# %%
data = cs[2][0].data
data += cs[3][0].data
data += cs[4][0].data
data += cs[5][0].data

# %%
c = cs[0][0]
c.data = data

# %%
plt.figure(figsize=(15, 8))
iplt.pcolormesh(c/86400.0)
plt.colorbar()
# Out:
# /Users/ph290/miniconda2/envs/mypython3/lib/python3.8/site-packages/iris/coords.py:1192: UserWarning: Coordinate 'longitude' is not bounded, guessing contiguous bounds.
#   warnings.warn('Coordinate {!r} is not bounded, guessing '
# /Users/ph290/miniconda2/envs/mypython3/lib/python3.8/site-packages/iris/coords.py:1192: UserWarning: Coordinate 'latitude' is not bounded, guessing contiguous bounds.
#   warnings.warn('Coordinate {!r} is not bounded, guessing '
