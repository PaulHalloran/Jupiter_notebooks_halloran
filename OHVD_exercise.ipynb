# %% [markdown]
# # Analysing Environmental 'Big Data'

# %% [markdown]
# ## Introduction

# %% [markdown]
# Example task:
#
# The circulation of the ocean is 'driven' by density contrasts. Dense water sinks below less-dense water, and vice versa.
#
# The Mediterranean is a very warm (warm = low density) but salty (salty = high density) ocean basin. Water 'spills' out of the Mediterranean into the open Atlantic Ocean. I want you to try and identify at what depths Mediterranean sourced waters can be found in the Atlantic Ocean.
#
# Read through the practical below, then edit the values and re-run the script (run it by clicking on the two right-facing arrows above (>>)). Once you think you've identified where the Mediterranean sources waters are within the Atlantic, let me know.
#
#
# Note to Paul. script in /Users/ph290/Documents/HalloranSync/documents/jupyter_github/Jupiter_notebooks_halloran

# %% [markdown]
# ## Setup
# This section imports some bits of code we will use later. If you're interested in what is going on behind the scenes, let me know.

# %%
import iris
import iris.quickplot as qplt
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import numpy
import plot_north_south_depth_section
import plot_east_west_depth_section
import plot_different_vertical_levels
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore", category=UserWarning)
# warnings.filterwarnings("ignore", category=matplotlib.cbook.MatplotlibDeprecationWarning)
# warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
# Out:
# /Users/ph290/miniconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# Here we are reading in the dataset we want to interrogate

# %%
cube = iris.load_cube('woa_theta.nc') # this example used World Ocean Atlas Temperature data

# %% [markdown]
# ## Analysing the data
#
# The three plots below allow you to explore the dataset.
# Edit the numbers in green, and re-run the script (>>) and explore what the plots are telling you

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ### Plot data at a certain depth level

# %%
depth = 0 # depth in meters

# %% [markdown]
# The code below produces the plot. Note, white areas are where there is no data. Typically land.

# %%
plot_different_vertical_levels.plot(depth,cube)

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ### Latitude v. depth plots
# Specify the latitude and longitude values that describe the region you want to explore, then run the script (>>) and examine the plot.

# %%
westernmost_longitude = -100.0 # this should be a value between -180 and 180 degrees
easternmost_longitude = 0.0 # this should be a value between -180 and 180 degrees
southernmost_latitude = -90 # this should be a value between -90 and 90 degrees
northernmost_latitude = 90 # this should be a value between -90 and 90 degrees

# %% [markdown]
# The code below produces the plot. Note, white areas are where there is no data. Typically land.

# %%
plot_north_south_depth_section.plot(westernmost_longitude,easternmost_longitude,southernmost_latitude,northernmost_latitude,cube)

# %% [markdown]
# Play with the latitude and longitude values in the box below, then run the script to plot up East-West sections down through the ocean for those regions

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ### Longitude v. depth plots
# Specify the latitude and longitude values that describe the region you want to explore, then run the script (>>) and examine the plot.

# %%
westernmost_longitude = -180 # this should be a value between -180 and 180 degrees
easternmost_longitude = 180 # this should be a value between -180 and 180 degrees
southernmost_latitude = -10 # this should be a value between -90 and 90 degrees
northernmost_latitude = 10 # this should be a value between -90 and 90 degrees

# %% [markdown]
# The code below produces the plot. Note, white areas are where there is no data. Typically land.

# %%
plot_east_west_depth_section.plot(westernmost_longitude,easternmost_longitude,southernmost_latitude,northernmost_latitude,cube)
